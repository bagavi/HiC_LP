# %%
import visualize, sys
# %matplotlib inline
folder = 'real_dataset_experiments/Gasterosteus/error_rates/'

# %%
for chromosome in range(1,11):
    visualize.plotvariable(folder, str(chromosome))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-1f07a15baed6> in <module>()
#       1 for chromosome in range(1,11):
# ----> 2     visualize.plotvariable(folder, str(chromosome))
#
# /data/vivek/HIC_project/AllPaths/code/visualize.py in plotvariable(folder, chromosome)
#      77     LP_greedy_file     = folder+"variable_LP_stricter_greedy"+chromosome+".csv"
#      78     BP_greedy_file     = folder+"variable_BP_stricter_greedy"+chromosome+".csv"
# ---> 79     plot(simple_greedy_file, merge_greedy_file, LP_greedy_file, BP_greedy_file)
#      80     plt.title("Variable contigs of chromosome "+chromosome, fontsize=30)
#      81     plt.show()
#
# /data/vivek/HIC_project/AllPaths/code/visualize.py in plot(simple_greedy_file, merge_greedy_file, lp_greedy_file, bp_greedy_file)
#      33
# ...

# %%
for chromosome in range(1,11):
    visualize.plot_100k(folder, str(chromosome), .4)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-4f4601052e45> in <module>()
#       1 for chromosome in range(1,11):
# ----> 2     visualize.plot_100k(folder, str(chromosome), .4)
#
# /data/vivek/HIC_project/AllPaths/code/visualize.py in plot_100k(folder, chromosome, xlim)
#      86     LP_greedy_file     = folder+"100000_LP_greedy_chr"+chromosome+".csv"
#      87     BP_greedy_file     = folder+"100000_BP_greedy_chr"+chromosome+".csv"
# ---> 88     plot(simple_greedy_file, merge_greedy_file, LP_greedy_file, BP_greedy_file)
#      89     plt.title("Variable contigs of chromosome "+chromosome)
#      90     plt.show()
#
# /data/vivek/HIC_project/AllPaths/code/visualize.py in plot(simple_greedy_file, merge_greedy_file, lp_greedy_file, bp_greedy_file)
#      33
#      34 def plot(simple_greedy_file, merge_greedy_file, lp_greedy_file, bp_greedy_file):
# ...
