# %%
import visualize
# %matplotlib inline
folder = 'data/Aedes_aegypti/HIC001/error_rates/'

# %%
for chromosome in range(1,4):
    visualize.plotvariable(folder, str(chromosome))

# %%
for chromosome in range(1,4):
    visualize.plot_100k(folder, str(chromosome))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-5df70c18e801> in <module>()
#       1 for chromosome in range(1,4):
# ----> 2     visualize.plot_100k(folder, str(chromosome))
#
# /data/vivek/HIC_project/AllPaths/code/visualize.pyc in plot_100k(folder, chromosome)
#      86     LP_greedy_file     = folder+"100000_LP_greedy_chr"+chromosome+".csv"
#      87     BP_greedy_file     = folder+"100000_BP_greedy_chr"+chromosome+".csv"
# ---> 88     plot(simple_greedy_file, merge_greedy_file, LP_greedy_file, BP_greedy_file)
#      89     plt.title("Variable contigs of chromosome "+chromosome)
#      90     plt.show()
#
# /data/vivek/HIC_project/AllPaths/code/visualize.pyc in plot(simple_greedy_file, merge_greedy_file, lp_greedy_file, bp_greedy_file)
#      33
#      34 def plot(simple_greedy_file, merge_greedy_file, lp_greedy_file, bp_greedy_file):
# ---> 35     sg_sf_array, sg_error_array, sg_fp_array = return_results(simple_greedy_file)
#      36     mg_sf_array, mg_error_array, mg_fp_array = return_results(merge_greedy_file)
#      37     lp_sf_array, lp_error_array, lp_fp_array = return_results(lp_greedy_file)
#
# /data/vivek/HIC_project/AllPaths/code/visualize.pyc in return_results(filepath)
#       9
#      10 def return_results(filepath):
# ---> 11     f = open(filepath, 'rb')
#      12     reader = csv.reader(f)
#      13     results = []
#
# IOError: [Errno 2] No such file or directory: 'data/Aedes_aegypti/HIC001/error_rates/100000_simple_greedy_chr1.csv'
